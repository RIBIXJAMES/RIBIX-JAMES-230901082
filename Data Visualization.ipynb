# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.arange(0,3*(np.pi),0.2)
y=np.sin(x)
print(plt.plot(x,y))
print(plt.show())
# Out:
# [<matplotlib.lines.Line2D object at 0x0000029274128890>]
# None

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints = np.array([0,10])
ypoints = np.array([20,100])
print(plt.plot(xpoints,ypoints))
print(plt.show())
# Out:
# [<matplotlib.lines.Line2D object at 0x00000201A2C38BD0>]
# None

# %%
x = np.array([0,5])
y = np.array([0,25])
print(plt.plot(x,y,marker='p'))
print(plt.show())
# Out:
# [<matplotlib.lines.Line2D object at 0x00000201A2D48F50>]
# None

# %%
xpoints = np.array([1,2,6,8])
ypoints = np.array([3,8,1,10])
print(plt.plot(xpoints,ypoints))
print(plt.show())
# Out:
# [<matplotlib.lines.Line2D object at 0x00000201A36355D0>]
# None

# %%
ypoints = np.array([5,7,1,0,3])
print(plt.plot(ypoints))
print(plt.show())
# Out:
# [<matplotlib.lines.Line2D object at 0x00000201A3600610>]
# None
